# %%
pip install pandas openpyxl
# Out:
# ...
#
# ...

# %%
pip install pandas matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as pl

# %%
import pandas as pd
file_path = 'C:/Users/Thandiswa/Downloads/archive/prices.csv'
try:
    prices_df = pd.read_csv(file_path)
    print(prices_df.head())
except FileNotFoundError:
    print(f"File not found: {file_path}")
except pd.errors.EmptyDataError:
    print("No data: The file is empty")
except pd.errors.ParserError:
    print("Parse error: There was a problem parsing the file")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#   Price Dates  Bhindi (Ladies finger)  Tomato  Onion  Potato  Brinjal  Garlic  \
# 0  01-01-2023                    35.0      18   22.0      20       30      50
# 1  02-01-2023                    35.0      16   22.0      20       30      55
# 2  03-01-2023                    35.0      16   21.0      20       30      55
# 3  04-01-2023                    30.0      16   21.0      22       25      55
# 4  08-01-2023                    35.0      16   20.0      21       25      55
#
#    Peas  Methi  Green Chilli  Elephant Yam (Suran)
# 0    25      8          45.0                    25
# 1    25      7          40.0                    25
# 2    25      7          40.0                    25
# 3    25      7          40.0                    25
# 4    22      6          35.0                    25

# %%
print("Length of 'Price Dates':", len(data["Price Dates"]))
print("Length of 'Bhindi (Ladies finger)':", len(data["Bhindi (Ladies finger)"]))
print("Length of 'Cauliflower':", len(data["Cauliflower"]))
print("Length of 'Cucumber':", len(data["Cucumber"]))
print("Length of 'Tomato':", len(data["Tomato"]))
# Out:
# Length of 'Price Dates': 220
# Length of 'Bhindi (Ladies finger)': 88
# Length of 'Cauliflower': 88
# Length of 'Cucumber': 88
# Length of 'Tomato': 100

# %%
correct_length = len(data["Price Dates"])
def adjust_length(lst, length):
    return lst[:length] + [None] * (length - len(lst))

data["Bhindi (Ladies finger)"] = adjust_length(data["Bhindi (Ladies finger)"], correct_length)
data["Cauliflower"] = adjust_length(data["Cauliflower"], correct_length)
data["Cucumber"] = adjust_length(data["Cucumber"], correct_length)
data["Tomato"] = adjust_length(data["Tomato"], correct_length)

# %%
import pandas as pd
df = pd.DataFrame(data)
df['Price Dates'] = pd.to_datetime(df['Price Dates'], dayfirst=True, errors='coerce')
df.set_index('Price Dates', inplace=True)

print(df.head())
# Out:
#              Bhindi (Ladies finger)  Cauliflower  Cucumber  Tomato
# Price Dates
# 2023-01-01                     35.0         35.0      50.0    45.0
# 2023-01-02                     35.0         35.0      50.0    50.0
# 2023-01-03                     35.0         35.0      55.0    50.0
# 2023-01-04                     30.0         30.0      55.0    50.0
# 2023-01-08                     35.0         35.0      55.0    45.0

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))

plt.subplot(2, 2, 1)
plt.plot(df.index, df['Bhindi (Ladies finger)'], marker='o', linestyle='-', color='b')
plt.title('Bhindi (Ladies finger) Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(df.index, df['Cauliflower'], marker='o', linestyle='-', color='g')
plt.title('Cauliflower Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(df.index, df['Cucumber'], marker='o', linestyle='-', color='r')
plt.title('Cucumber Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(df.index, df['Tomato'], marker='o', linestyle='-', color='orange')
plt.title('Tomato Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Analysis of Price Trends for Vegetables

This document provides an analysis of the price trends for four types of vegetables: Bhindi (Ladies finger), Cauliflower, Cucumber, and Tomato. The data spans from January 2023 to October 2023. The plots below illustrate how the prices of these vegetables have changed over time.

## 1. Bhindi (Ladies Finger) Prices

The plot for Bhindi (Ladies finger) shows the following observations:
- **Initial Price**: The price started at 35 units and experienced fluctuations throughout the year.
- **Trend**: Prices exhibited a general upward trend from March 2023, peaking up again around May 2023.
- **Fluctuations**: There were noticeable dips and spikes. This could be due to seasonal changes or supply chain issues.

# %%
## 2. Cauliflower Prices

The plot for Cauliflower reveals:
- **Initial Price**: Similar to Bhindi, Cauliflower prices began at 35 units.
- **Trend**: The price also showed an increasing trend, with significant jumps around May and September 2023.
- **Consistency**: Prices were relatively stable with fewer extreme fluctuations compared to Bhindi.

# %%
## 3. Cucumber Prices

The Cucumber price plot demonstrates:
- **Initial Price**: Prices started at 50 units and showed a noticeable increase throughout the year.
- **Trend**: There is a clear upward trend, with prices rising more sharply after May 2023.
- **Volatility**: Unlike the other vegetables, Cucumber prices experienced larger spikes, especially noticeable in July and August.

# %%
## 4. Tomato Prices

The plot for Tomato prices indicates:
- **Initial Price**: Tomato prices began at 45 units and generally trended upwards.
- **Trend**: Prices increased steadily with some fluctuations, peaking around May and September 2023.
- **Consistency**: The trend for Tomato is more gradual compared to Cucumber, but shows a steady increase over time.

## Summary

- **Overall Trends**: Most vegetables exhibited an upward trend in prices over the year. However, the rate of increase and volatility varied between different vegetables.
- **Comparisons**:
  - **Bhindi and Cauliflower**: Both show a similar pattern with fluctuations, but Cauliflower prices are slightly more stable.
  - **Cucumber**: This vegetable shows the highest volatility with significant price spikes.
  - **Tomato**: Prices increase steadily but with less volatility compared to Cucumber.

This analysis provides insights into the price dynamics of these vegetables, which could be useful for both consumers and suppliers in understanding market trends.

---

*Note: The plots above are visual representations of the data and should be interpreted with the context of market conditions and seasonal variations.*
